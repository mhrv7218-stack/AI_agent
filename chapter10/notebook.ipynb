# %% [markdown]
# # 要件定義書生成AIエージェントの開発

# %%
# !git clone https://github.com/GenerativeAgents/agent-book.git
# Out:
# Cloning into 'agent-book'...
# remote: Enumerating objects: 533, done.
# remote: Counting objects: 100% (199/199), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 533 (delta 166), reused 140 (delta 140), pack-reused 334 (from 1)
# Receiving objects: 100% (533/533), 1.74 MiB | 6.38 MiB/s, done.
# Resolving deltas: 100% (297/297), done.

# %%
# !pip install langchain-core==0.3.0 langchain-openai==0.2.0 langgraph==0.2.22 python-dotenv==1.0.1 pydantic==2.10.6
# Out:
# Collecting langchain-core==0.3.0
#   Downloading langchain_core-0.3.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting langchain-openai==0.2.0
#   Downloading langchain_openai-0.2.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting langgraph==0.2.22
#   Downloading langgraph-0.2.22-py3-none-any.whl.metadata (13 kB)
# Collecting python-dotenv==1.0.1
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting pydantic==2.10.6
#   Downloading pydantic-2.10.6-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.12/dist-packages (from langchain-core==0.3.0) (6.0.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.12/dist-packages (from langchain-core==0.3.0) (1.33)
# Collecting langsmith<0.2.0,>=0.1.117 (from langchain-core==0.3.0)
#   Downloading langsmith-0.1.147-py3-none-any.whl.metadata (14 kB)
# Collecting packaging<25,>=23.2 (from langchain-core==0.3.0)
#   Downloading packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting tenacity!=8.4.0,<9.0.0,>=8.1.0 (from langchain-core==0.3.0)
#   Downloading tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.12/dist-packages (from langchain-core==0.3.0) (4.16.0)
# Collecting openai<2.0.0,>=1.40.0 (from langchain-openai==0.2.0)
#   Downloading openai-1.109.1-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: tiktoken<1,>=0.7 in /usr/local/lib/python3.12/dist-packages (from langchain-openai==0.2.0) (0.13.0)
# Collecting langgraph-checkpoint<2.0.0,>=1.0.2 (from langgraph==0.2.22)
#   Downloading langgraph_checkpoint-1.0.12-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic==2.10.6) (0.7.0)
# Collecting pydantic-core==2.27.2 (from pydantic==2.10.6)
#   Downloading pydantic_core-2.27.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core==0.3.0) (3.1.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<2.0.0,>=1.0.2->langgraph==0.2.22) (1.2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<0.2.0,>=0.1.117->langchain-core==0.3.0) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<0.2.0,>=0.1.117->langchain-core==0.3.0) (3.11.9)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.12/dist-packages (from langsmith<0.2.0,>=0.1.117->langchain-core==0.3.0) (2.32.4)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<0.2.0,>=0.1.117->langchain-core==0.3.0) (1.0.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.2.0) (4.14.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.2.0) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.2.0) (0.16.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.2.0) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.2.0) (4.67.3)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from tiktoken<1,>=0.7->langchain-openai==0.2.0) (2025.11.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.40.0->langchain-openai==0.2.0) (3.18)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.117->langchain-core==0.3.0) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.117->langchain-core==0.3.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.117->langchain-core==0.3.0) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.117->langchain-core==0.3.0) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.117->langchain-core==0.3.0) (2.5.0)
# Downloading langchain_core-0.3.0-py3-none-any.whl (405 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 405.1/405.1 kB 5.5 MB/s eta 0:00:00
# Downloading langchain_openai-0.2.0-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.5/51.5 kB 4.3 MB/s eta 0:00:00
# Downloading langgraph-0.2.22-py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.5/98.5 kB 9.1 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading pydantic-2.10.6-py3-none-any.whl (431 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.7/431.7 kB 16.8 MB/s eta 0:00:00
# Downloading pydantic_core-2.27.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 39.6 MB/s eta 0:00:00
# Downloading langgraph_checkpoint-1.0.12-py3-none-any.whl (17 kB)
# Downloading langsmith-0.1.147-py3-none-any.whl (311 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.8/311.8 kB 26.1 MB/s eta 0:00:00
# Downloading openai-1.109.1-py3-none-any.whl (948 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.6/948.6 kB 51.9 MB/s eta 0:00:00
# Downloading packaging-24.2-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 5.8 MB/s eta 0:00:00
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Installing collected packages: tenacity, python-dotenv, pydantic-core, packaging, pydantic, openai, langsmith, langchain-core, langgraph-checkpoint, langchain-openai, langgraph
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.1.4
#     Uninstalling tenacity-9.1.4:
#       Successfully uninstalled tenacity-9.1.4
#   Attempting uninstall: python-dotenv
#     Found existing installation: python-dotenv 1.2.2
#     Uninstalling python-dotenv-1.2.2:
#       Successfully uninstalled python-dotenv-1.2.2
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.46.4
#     Uninstalling pydantic_core-2.46.4:
#       Successfully uninstalled pydantic_core-2.46.4
#   Attempting uninstall: packaging
#     Found existing installation: packaging 26.2
#     Uninstalling packaging-26.2:
#       Successfully uninstalled packaging-26.2
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.13.4
#     Uninstalling pydantic-2.13.4:
#       Successfully uninstalled pydantic-2.13.4
#   Attempting uninstall: openai
#     Found existing installation: openai 2.45.0
#     Uninstalling openai-2.45.0:
#       Successfully uninstalled openai-2.45.0
#   Attempting uninstall: langsmith
#     Found existing installation: langsmith 0.10.2
#     Uninstalling langsmith-0.10.2:
#       Successfully uninstalled langsmith-0.10.2
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.4.9
#     Uninstalling langchain-core-1.4.9:
#       Successfully uninstalled langchain-core-1.4.9
#   Attempting uninstall: langgraph-checkpoint
#     Found existing installation: langgraph-checkpoint 4.1.1
#     Uninstalling langgraph-checkpoint-4.1.1:
#       Successfully uninstalled langgraph-checkpoint-4.1.1
#   Attempting uninstall: langgraph
#     Found existing installation: langgraph 1.2.9
#     Uninstalling langgraph-1.2.9:
#       Successfully uninstalled langgraph-1.2.9
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langgraph-prebuilt 1.1.0 requires langchain-core>=1.3.1, but you have langchain-core 0.3.0 which is incompatible.
# langgraph-prebuilt 1.1.0 requires langgraph-checkpoint<5.0.0,>=2.1.0, but you have langgraph-checkpoint 1.0.12 which is incompatible.
# langgraph-sdk 0.4.2 requires langchain-core<2,>=1.4.0, but you have langchain-core 0.3.0 which is incompatible.
# langchain 1.3.13 requires langchain-core<2.0.0,>=1.4.9, but you have langchain-core 0.3.0 which is incompatible.
# langchain 1.3.13 requires langgraph<1.3.0,>=1.2.5, but you have langgraph 0.2.22 which is incompatible.
# google-adk 2.4.0 requires pydantic<3,>=2.12, but you have pydantic 2.10.6 which is incompatible.
# google-adk 2.4.0 requires tenacity<10,>=9, but you have tenacity 8.5.0 which is incompatible.
# google-genai 2.11.0 requires pydantic<3.0.0,>=2.12.5, but you have pydantic 2.10.6 which is incompatible.
# Successfully installed langchain-core-0.3.0 langchain-openai-0.2.0 langgraph-0.2.22 langgraph-checkpoint-1.0.12 langsmith-0.1.147 openai-1.109.1 packaging-24.2 pydantic-2.10.6 pydantic-core-2.27.2 python-dotenv-1.0.1 tenacity-8.5.0

# %%
# 以下のエラーの対策として、langchainの動作確認済みバージョンをインストール
# AttributeError: module 'langchain' has no attribute 'verbose'

# !pip install --no-deps langchain==0.3.23
# Out:
# WARNING: Ignoring invalid distribution ~angchain (/usr/local/lib/python3.12/dist-packages)
# Collecting langchain==0.3.23
#   Using cached langchain-0.3.23-py3-none-any.whl.metadata (7.8 kB)
# Using cached langchain-0.3.23-py3-none-any.whl (1.0 MB)
# Installing collected packages: langchain
# WARNING: Ignoring invalid distribution ~angchain (/usr/local/lib/python3.12/dist-packages)
# Successfully installed langchain

# %%
# %cd agent-book
# %cd chapter10
# Out:
# /content/agent-book
# /content/agent-book/chapter10

# %%
import os
from google.colab import userdata

os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_ENDPOINT"] = "https://api.smith.langchain.com"
os.environ["LANGCHAIN_API_KEY"] = userdata.get("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_PROJECT"] = "agent-book"

# %%
# !python -m documentation_agent.main --task "スマートフォン向けの健康管理アプリを開発したい"
# Out:
# # 健康管理アプリ開発要件文書
#
# ## 1. プロジェクト概要
# 本プロジェクトは、スマートフォン向けの健康管理アプリを開発することを目的としています。ユーザーが日常生活の中で健康を維持しやすくするために、直感的で使いやすいインターフェースと、個々のライフスタイルに合わせたパーソナライズされた機能を提供します。特に、忙しい現代人が無理なく健康管理を続けられるように設計されています。
#
# ## 2. 主要機能
# 1. **シンプルで直感的なインターフェース**: 複雑な操作を排除し、ユーザーが直感的に操作できるデザインを採用します。
# 2. **自動データ同期**: スマートウォッチやフィットネストラッカーと連携し、自動でデータを同期します。
# 3. **リマインダー機能**: 水分補給、ストレッチ、休憩を促すリマインダーを提供します。
# 4. **短時間でできるエクササイズ提案**: 5分や10分でできるエクササイズを提案します。
# 5. **パーソナライズされた目標設定**: ユーザーのライフスタイルに合わせた目標設定機能を提供します。
# 6. **進捗の可視化**: 活動や健康状態の進捗をグラフやチャートで視覚的に確認できます。
# 7. **簡単な食事記録**: 食事の写真を撮るだけでカロリーや栄養素を自動で記録します。
# 8. **ストレス管理機能**: 呼吸法や瞑想のガイドを提供します。
# 9. **運動トラッキング**: 歩数、ランニング距離、消費カロリーを自動で記録します。
# 10. **健康診断データの管理**: 健康診断の結果を入力し、リスクの変化を追跡します。
# 11. **レシピ提案**: 栄養バランスの良いレシピを提案します。
# 12. **コミュニティ機能**: ユーザー同士が交流し、モチベーションを高めるための機能を提供します。
#
# ## 3. 非機能要件
# 1. **パフォーマンス**: アプリはスムーズに動作し、遅延なくデータを処理します。
# 2. **セキュリティ**: ユーザーの個人情報を保護し、データの安全性を確保します。
# 3. **ユーザビリティ**: 初心者でも簡単に操作できるように、シンプルで直感的なUIを提供します。
# 4. **互換性**: iOSおよびAndroidプラットフォームで動作すること。
#
# ## 4. 制約条件
# 1. **開発期間**: 6ヶ月以内にリリースすること。
# 2. **予算**: 開発およびマーケティングにかかる費用は、事前に設定された予算内で収めること。
# 3. **技術的制約**: 既存のフィットネストラッカーやスマートウォッチとの互換性を確保すること。
#
# ## 5. ターゲットユーザー
# - 忙しい日常を送るビジネスパーソン
# - 健康志向の高い若年層
# - 生活習慣病のリスクを管理したい中高年層
# - 栄養学に興味がある学生
#
# ## 6. 優先順位
# 1. **シンプルなインターフェースと自動データ同期**: ユーザーの継続利用を促進するために最優先で実装。
# 2. **リマインダー機能と短時間エクササイズ提案**: ユーザーの健康習慣をサポートするために優先度高。
# 3. **パーソナライズされた目標設定と進捗の可視化**: ユーザーのモチベーション維持に重要。
# 4. **食事記録とストレス管理機能**: 健康管理の幅を広げるために実装。
#
# ## 7. リスクと軽減策
# 1. **技術的な問題**: データ同期やアプリのパフォーマンスに問題が発生する可能性。
#    - **軽減策**: 開発初期に徹底したテストを行い、問題を早期に発見・修正する。
# 2. **ユーザーの継続利用が低下するリスク**: アプリの利用が続かない可能性。
#    - **軽減策**: ユーザーインタビューを基にしたUXデザインの改善と、コミュニティ機能の強化。
# 3. **セキュリティリスク**: ユーザーデータの漏洩。
#    - **軽減策**: データ暗号化と定期的なセキュリティレビューを実施する。
#
# この要件文書は、ユーザーのニーズを満たし、健康管理をサポートするためのアプリ開発の指針となります。
